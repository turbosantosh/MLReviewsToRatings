# %%
import pandas as pd

# %%
path_to_data = '/Users/Santosh/PROJECTS/ZOCDOC_ML/DATA/'

# %%
docData = pd.read_csv(path_to_data + 'train.csv')

# %%
docData.head(2)
# Out:
#           DocName DocDegree      Location                   PatientName  \
# 0  Dr. Liana Dao         MD  New York  NY  Ashley M. (Verified Patient)
# 1  Dr. Liana Dao         MD  New York  NY            a Verified Patient
#
#       ReviewDate  OverallRating  BedsideMannerRating  WaitTimeRating  \
# 0  April 7  2015              5                    5               5
# 1  April 6  2015              5                    5               5
#
#                                               Review
# 0  Liana Dao is amazing ! She made me feel totall...
# 1  I was in a jam and couldn't get to my regular ...

# %%
len(docData.columns)
# Out:
# 9

# %%
print len(docData)
# Out:
# 59998

# %%
docData.describe()
# Out:
#        OverallRating  BedsideMannerRating  WaitTimeRating     isGood  \
# count   59462.000000         59462.000000    59462.000000      59462
# mean        4.623541             4.672093        4.325334  0.9048972
# std         0.934691             0.813151        0.826189  0.2933593
# min         1.000000             1.000000        1.000000      False
# 25%         5.000000             5.000000        4.000000          1
# 50%         5.000000             5.000000        5.000000          1
# 75%         5.000000             5.000000        5.000000          1
# max         5.000000             5.000000        5.000000       True
#
#        ReviewWordCount
# count     59462.000000
# mean         32.016902
# std          36.879769
# min           0.000000
# 25%          10.000000
# 50%          22.000000
# 75%          41.000000
# max         606.000000

# %%
docData[['DocName', 'OverallRating', 'BedsideMannerRating', 'WaitTimeRating']].groupby('DocName').mean().sort('OverallRating', ascending=True).head(5)
# Out:
#                        OverallRating  BedsideMannerRating  WaitTimeRating
# DocName
# Dr. Joseph Fedrick          2.000000             2.000000        1.000000
# Dr. Samir Amin              3.000000             4.200000        3.000000
# Dr. Provat Das              3.307692             3.230769        3.307692
# Dr. Michael Aziz            3.380000             3.540000        3.960000
# Dr. Napoleon Savescu        3.454545             3.636364        2.818182

# %%
# most doctors are rated high
docData[['OverallRating', 'BedsideMannerRating', 'WaitTimeRating']].mean()
# Out:
# OverallRating          4.625871
# BedsideMannerRating    4.674489
# WaitTimeRating         4.327111
# dtype: float64

# %%
def mean(series):
    " " " Returns the avg of the panda Series " " "
    return series.mean()
def count(series):
    " " " Returns the avg of the panda Series " " "
    return series.count()
docData[['DocName', 'OverallRating', 'BedsideMannerRating', 'WaitTimeRating', 'Review']].groupby('DocName').agg({'OverallRating': mean, 'BedsideMannerRating': mean, 'WaitTimeRating': mean, 'Review': count }).sort('OverallRating', ascending=True).head(20)
# Out:
#                             OverallRating  Review  BedsideMannerRating  \
# DocName
# Dr. Joseph Fedrick               2.000000       2             2.000000
# Dr. Samir Amin                   3.000000       5             4.200000
# Dr. Provat Das                   3.307692      13             3.230769
# Dr. Michael Aziz                 3.380000     450             3.540000
# Dr. Napoleon Savescu             3.454545      33             3.636364
# Dr. Elizabeth Muss               3.454545     154             3.454545
# Dr. Peter Agho                   3.500000      48             4.000000
# Dr. David Mack                   3.588235      85             3.941176
# Dr. Bella Gelfinbein             3.600000      40             3.550000
# Dr. Dana Jane Saltzman           3.762500     400             3.912500
# Dr. Lev Paukman                  3.833333      30             4.333333
# Dr. Hari Polavarapu              3.857143      14             4.285714
# Dr. Yekaterina Kuznetsova        3.887500     320             4.062500
# Dr. Alfonso Ortiz                3.934783     230             3.913043
# Dr. Dov Grant                    3.937500     128             4.125000
# Dr. Melanie MacLennan            3.970588     340             4.000000
# Dr. Syed Hussaini                4.000000      12             4.000000
# Dr. Michael Platzman             4.000000      16             4.750000
# Dr. Muhammad M Haque             4.000000       8             4.000000
# Dr. Shital Rana                  4.000000       2             4.000000
#
#                             WaitTimeRating
# DocName
# Dr. Joseph Fedrick                1.000000
# Dr. Samir Amin                    3.000000
# Dr. Provat Das                    3.307692
# Dr. Michael Aziz                  3.960000
# Dr. Napoleon Savescu              2.818182
# Dr. Elizabeth Muss                3.727273
# Dr. Peter Agho                    3.875000
# Dr. David Mack                    3.058824
# Dr. Bella Gelfinbein              2.600000
# Dr. Dana Jane Saltzman            4.325000
# Dr. Lev Paukman                   3.500000
# Dr. Hari Polavarapu               2.928571
# Dr. Yekaterina Kuznetsova         3.750000
# Dr. Alfonso Ortiz                 3.717391
# Dr. Dov Grant                     4.250000
# Dr. Melanie MacLennan             4.352941
# Dr. Syed Hussaini                 4.000000
# Dr. Michael Platzman              4.750000
# Dr. Muhammad M Haque              3.500000
# Dr. Shital Rana                   3.500000

# %%
docData[['OverallRating', 'BedsideMannerRating', 'WaitTimeRating', 'Review']].groupby('OverallRating').agg({'OverallRating': mean, 'BedsideMannerRating': mean, 'WaitTimeRating': mean, 'Review': count }).sort('OverallRating', ascending=True).head(20)
# Out:
#                OverallRating  Review  BedsideMannerRating  WaitTimeRating
# OverallRating
# 1                          1    1827             1.774494        3.218938
# 2                          2    2120             2.686792        3.540094
# 3                          3    1718             3.465076        3.455763
# 4                          4    5343             4.380311        3.896500
# 5                          5   48989             4.943152        4.480016

# %%
# There are more number of people who have rate higher than lower.

# %%
docData[['Location', 'OverallRating', 'BedsideMannerRating', 'WaitTimeRating', 'Review']].groupby('Location').agg({'OverallRating': mean, 'BedsideMannerRating': mean, 'WaitTimeRating': mean, 'Review': count }).sort('OverallRating', ascending=True).head(20)
# Out:
#                       OverallRating  Review  BedsideMannerRating  \
# Location
# Bronx  NY                  4.340755    1033             4.403679
# North Bergen  NJ           4.344828      29             4.551724
# Dumont  NJ                 4.434783      23             4.521739
# Brooklyn  NY               4.517372    1842             4.587948
# Jersey City  NJ            4.520921     478             4.610879
# Huntington  NY             4.550000      40             4.650000
# Astoria  NY                4.555006     808             4.614339
# New York  NY               4.635142   54920             4.682666
# Teaneck  NJ                4.641026      39             4.717949
# New York   NY              4.675000     400             4.675000
# Jamaica  NY                4.793651     126             4.841270
# Flushing  NY               4.800000      80             4.775000
# Englewood  NJ              4.882979      94             4.893617
# Fort Lee  NJ               4.914286      35             4.942857
# Jackson Heights  NY        5.000000      24             5.000000
# Edgewater  NJ              5.000000       4             5.000000
# Long Island City  NY       5.000000       8             5.000000
# Morris  CT                 5.000000      14             5.000000
#
#                       WaitTimeRating
# Location
# Bronx  NY                   3.647628
# North Bergen  NJ            3.827586
# Dumont  NJ                  3.956522
# Brooklyn  NY                4.024430
# Jersey City  NJ             4.200837
# Huntington  NY              4.775000
# Astoria  NY                 4.074166
# New York  NY                4.352440
# Teaneck  NJ                 4.102564
# New York   NY               4.575000
# Jamaica  NY                 4.555556
# Flushing  NY                4.200000
# Englewood  NJ               4.531915
# Fort Lee  NJ                4.000000
# Jackson Heights  NY         5.000000
# Edgewater  NJ               5.000000
# Long Island City  NY        4.000000
# Morris  CT                  4.714286

# %%
# Doctors from Bronx etc are low rated than Long Island Doctors.

# %%
docData.shape
# Out:
# (59998, 9)

# %%
docData = docData.dropna()

# %%
docData.count()
# Out:
# DocName                59462
# DocDegree              59462
# Location               59462
# PatientName            59462
# ReviewDate             59462
# OverallRating          59462
# BedsideMannerRating    59462
# WaitTimeRating         59462
# Review                 59462
# dtype: int64

# %%
# Create a feature for isGood
# Assumption:
# Reviews Rated 4,5 are good
# Reviews Rated 1,2,3 are bad
docData['isGood'] = docData.OverallRating.apply(lambda x: x-3 >0)

# %%
docData
# Out:
#                      DocName DocDegree      Location  \
# 0             Dr. Liana Dao         MD  New York  NY
# 1             Dr. Liana Dao         MD  New York  NY
# 2             Dr. Liana Dao         MD  New York  NY
# 3             Dr. Liana Dao         MD  New York  NY
# 4             Dr. Liana Dao         MD  New York  NY
# 5             Dr. Liana Dao         MD  New York  NY
# 6             Dr. Liana Dao         MD  New York  NY
# 7             Dr. Liana Dao         MD  New York  NY
# 8             Dr. Liana Dao         MD  New York  NY
# 9             Dr. Liana Dao         MD  New York  NY
# 10            Dr. Liana Dao         MD  New York  NY
# 11            Dr. Liana Dao         MD  New York  NY
# 16      Dr. Robert Shalhoub         MD  New York  NY
# 17      Dr. Robert Shalhoub         MD  New York  NY
# 18      Dr. Robert Shalhoub         MD  New York  NY
# 19      Dr. Robert Shalhoub         MD  New York  NY
# 20      Dr. Robert Shalhoub         MD  New York  NY
# 21       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 22       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 23       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 24       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 25       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 26       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 27       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 28       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 29       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 30       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 31       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 32       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# 33       Dr. Janelle Sunwoo         MD  Brooklyn  NY
# ...                      ...       ...           ...
# 59968  Dr. Michael Raffinan         MD  New York  NY
# 59969  Dr. Michael Raffinan         MD  New York  NY
# 59970  Dr. Michael Raffinan         MD  New York  NY
# 59971  Dr. Michael Raffinan         MD  New York  NY
# 59972  Dr. Michael Raffinan         MD  New York  NY
# 59973  Dr. Michael Raffinan         MD  New York  NY
# 59974  Dr. Michael Raffinan         MD  New York  NY
# 59975  Dr. Michael Raffinan         MD  New York  NY
# 59976  Dr. Michael Raffinan         MD  New York  NY
# 59977  Dr. Michael Raffinan         MD  New York  NY
# 59978  Dr. Michael Raffinan         MD  New York  NY
# 59979  Dr. Michael Raffinan         MD  New York  NY
# 59980  Dr. Michael Raffinan         MD  New York  NY
# 59981  Dr. Michael Raffinan         MD  New York  NY
# 59982  Dr. Michael Raffinan         MD  New York  NY
# 59983  Dr. Michael Raffinan         MD  New York  NY
# 59984  Dr. Michael Raffinan         MD  New York  NY
# 59985  Dr. Michael Raffinan         MD  New York  NY
# 59986  Dr. Michael Raffinan         MD  New York  NY
# 59987  Dr. Michael Raffinan         MD  New York  NY
# 59988  Dr. Michael Raffinan         MD  New York  NY
# 59989  Dr. Michael Raffinan         MD  New York  NY
# 59990  Dr. Michael Raffinan         MD  New York  NY
# 59991  Dr. Michael Raffinan         MD  New York  NY
# 59992  Dr. Michael Raffinan         MD  New York  NY
# 59993  Dr. Michael Raffinan         MD  New York  NY
# 59994  Dr. Michael Raffinan         MD  New York  NY
# 59995  Dr. Michael Raffinan         MD  New York  NY
# 59996  Dr. Michael Raffinan         MD  New York  NY
# 59997  Dr. Michael Raffinan         MD  New York  NY
#
#                                PatientName              ReviewDate  \
# 0             Ashley M. (Verified Patient)           April 7  2015
# 1                       a Verified Patient           April 6  2015
# 2                       a Verified Patient    Less than a year ago
# 3                       a Verified Patient          August 5  2014
# 4                       a Verified Patient             May 5  2014
# 5                       a Verified Patient    More than a year ago
# 6               Erin H. (Verified Patient)          April 11  2014
# 7                       a Verified Patient          March 14  2014
# 8                       a Verified Patient           March 7  2014
# 9           Sharifah A. (Verified Patient)       February 19  2014
# 10                      a Verified Patient        January 29  2014
# 11                      a Verified Patient    More than a year ago
# 16                 V N. (Verified Patient)           July 14  2015
# 17             Jamie B. (Verified Patient)            July 1  2015
# 18              Lisa A. (Verified Patient)          March 26  2015
# 19           Michael C. (Verified Patient)          March 10  2015
# 20                      a Verified Patient  Less than 6 months ago
# 21             Chris G. (Verified Patient)           July 28  2015
# 22            Lucile H. (Verified Patient)           July 27  2015
# 23           Kavitha B. (Verified Patient)           July 24  2015
# 24           Gregory T. (Verified Patient)           July 22  2015
# 25            Ansley B. (Verified Patient)           July 20  2015
# 26          Patricia L. (Verified Patient)           July 17  2015
# 27              John I. (Verified Patient)           July 16  2015
# 28         Katherine A. (Verified Patient)           July 16  2015
# 29              Toby S. (Verified Patient)           July 13  2015
# 30                      a Verified Patient   Less than a month ago
# 31             Grace M. (Verified Patient)            July 9  2015
# 32                      a Verified Patient            July 9  2015
# 33                      a Verified Patient            July 8  2015
# ...                                    ...                     ...
# 59968         Temple S. (Verified Patient)           July 21  2015
# 59969       Charonda G. (Verified Patient)           July 10  2015
# 59970          Ellen B. (Verified Patient)   Less than a month ago
# 59971                   a Verified Patient            July 7  2015
# 59972           Jenn H. (Verified Patient)            July 2  2015
# 59973           Alan W. (Verified Patient)  Less than 3 months ago
# 59974                   a Verified Patient  Less than 3 months ago
# 59975       Kimberly H. (Verified Patient)            June 5  2015
# 59976         Corbin G. (Verified Patient)            June 4  2015
# 59977       Caroline R. (Verified Patient)            June 2  2015
# 59978         Amanda M. (Verified Patient)            May 27  2015
# 59979        Premika S. (Verified Patient)  Less than 3 months ago
# 59980         Joseph N. (Verified Patient)  Less than 3 months ago
# 59981       Caroline R. (Verified Patient)            May 13  2015
# 59982         Daniel C. (Verified Patient)            May 11  2015
# 59983          Maria Q. (Verified Patient)             May 5  2015
# 59984        Rebecca F. (Verified Patient)             May 4  2015
# 59985         Amelia V. (Verified Patient)             May 1  2015
# 59986         Vickie T. (Verified Patient)             May 1  2015
# 59987                   a Verified Patient          April 30  2015
# 59988                   a Verified Patient          April 23  2015
# 59989                   a Verified Patient          April 22  2015
# 59990                   a Verified Patient  Less than 6 months ago
# 59991                   a Verified Patient          March 31  2015
# 59992                   a Verified Patient  Less than 6 months ago
# 59993                   a Verified Patient  Less than 6 months ago
# 59994      Cindy Lou C. (Verified Patient)          March 26  2015
# 59995  Victor Andres R. (Verified Patient)          March 19  2015
# 59996         Corbin G. (Verified Patient)          March 17  2015
# 59997       Adrianne B. (Verified Patient)          March 17  2015
#
#        OverallRating  BedsideMannerRating  WaitTimeRating  \
# 0                  5                    5               5
# 1                  5                    5               5
# 2                  5                    5               4
# 3                  5                    5               4
# 4                  5                    5               5
# 5                  1                    4               5
# 6                  5                    5               5
# 7                  5                    5               5
# 8                  5                    5               4
# 9                  5                    4               4
# 10                 5                    5               3
# 11                 5                    5               4
# 16                 5                    5               4
# 17                 5                    5               5
# 18                 5                    5               4
# 19                 5                    5               4
# 20                 5                    5               5
# 21                 5                    5               5
# 22                 5                    5               4
# 23                 5                    5               5
# 24                 4                    4               5
# 25                 5                    5               5
# 26                 5                    5               5
# 27                 5                    5               5
# 28                 5                    5               5
# 29                 5                    5               5
# 30                 5                    5               5
# 31                 5                    5               5
# 32                 5                    5               5
# 33                 4                    5               5
# ...              ...                  ...             ...
# 59968              5                    5               5
# 59969              5                    5               5
# 59970              5                    5               4
# 59971              5                    5               4
# 59972              5                    5               5
# 59973              5                    5               4
# 59974              4                    5               5
# 59975              5                    5               4
# 59976              5                    5               4
# 59977              5                    5               4
# 59978              5                    5               5
# 59979              5                    5               5
# 59980              5                    5               4
# 59981              5                    5               5
# 59982              5                    5               5
# 59983              5                    5               5
# 59984              5                    5               4
# 59985              5                    5               4
# 59986              5                    5               5
# 59987              4                    5               5
# 59988              5                    5               5
# 59989              5                    5               4
# 59990              5                    5               5
# 59991              4                    5               5
# 59992              5                    5               5
# 59993              5                    5               5
# 59994              5                    4               5
# 59995              5                    5               4
# 59996              5                    5               5
# 59997              5                    5               5
#
#                                                   Review isGood
# 0      Liana Dao is amazing ! She made me feel totall...   True
# 1      I was in a jam and couldn't get to my regular ...   True
# 2      Dr. Dao was great - she took the time to expla...   True
# 3      Very knowledgeable and explained everything. P...   True
# 4      Liana was very pleasant and easy to deal with....   True
# 5      First issue is they don't tell you that this i...  False
# 6      Liana Dao was lovely. We were on our way to th...   True
# 7      Dr. Dao was very nice  attentive and considera...   True
# 8      Very knowledgeable and takes the time to make ...   True
# 9      She's very informative and i really appreciate...   True
# 10          I like her a lot. She explains things well.    True
# 11              She was amazing and and so professional    True
# 16     Dr. Shalhoub is a caring professional with gre...   True
# 17     I've been going to dr Shaloub for almost 12 ye...   True
# 18      Dr. Shaloub is a sensitive  caring physician ...   True
# 19     Dr. Shalhoub is everything that a doctor shoul...   True
# 20     I could not have been treated better. A wonder...   True
# 21     Was very happy with all of the service and hel...   True
# 22     The Leaf Medical offices are very pleasant  an...   True
# 23     I got my trains totally messed up this morning...   True
# 24     She listened thoroughly  took notes and came u...   True
# 25     Very patient  attentive doctor who answered al...   True
# 26     I see Dr. Sunwoo regularly because of an auto-...   True
# 27     Very good bedside manner  and she asked a lot ...   True
# 28     Reception staff were very friendly and courteo...   True
# 29     Really great attention and support from Dr Sun...   True
# 30     Everything was excellent. One of the best expe...   True
# 31            Very kind and professional. Will be back.    True
# 32                                All in all  excellent.   True
# 33     First visit for my annual exam. Was seen right...   True
# ...                                                  ...    ...
# 59968  Dr. Raffinan is the most compassionate doctor ...   True
# 59969  My first visit went very well. AS soon as i wa...   True
# 59970  Dr. Raffinan is a wonderful  caring doctor  wh...   True
# 59971  This was my first time seeing Dr. Raffinan. He...   True
# 59972  Dr Raffinan provides a level of care you just ...   True
# 59973              Very compassionate and professional.    True
# 59974  The doctor was great  but the nurse was rude a...   True
# 59975  Dr. Raffinan has a good bed-side manner  and h...   True
# 59976  Always a pleasure with Dr R. He totally humani...   True
# 59977  I think he's great! Always takes into account ...   True
# 59978  He took time to talk and discuss everything to...   True
# 59979  Very patient doctor. Asks all the right questi...   True
# 59980        First time at the office  and so far great.   True
# 59981  Dr. Raffinan was awesome! I have been looking ...   True
# 59982  I've seen Dr. Raffinan for years. He is extrao...   True
# 59983  Dr Raffinan is the best. He is extremely effic...   True
# 59984  Dr. Ruffinan was great. Took my concerns serio...   True
# 59985  Very impressed.  Listened and paraphrased   my...   True
# 59986  He is very present. He is clearly a busy docto...   True
# 59987  It was good! Was friendly  helpful  gave good ...   True
# 59988  Dr. Raffinan is a very good doctor. I have bee...   True
# 59989  Dr. Raffinan is calm  thorough and full of int...   True
# 59990  He made me feel very comfortable. He had a chi...   True
# 59991  This was my first visit (sick visit).  Was abl...   True
# 59992  Always thorough and inquisitive and focused on...   True
# 59993  He's the most thorough doctor I've met in New ...   True
# 59994  Excellent visit. Was seen immediately  minimal...   True
# 59995  He was great  he really goes through every iss...   True
# 59996  Dr Raffinan is excellent. Very cool to talk to...   True
# 59997  The doctor was thorough and took a holistic ap...   True
#
# [59462 rows x 10 columns]

# %%
#docData['Review'] = docData['Review'].isnull()#.str.replace('nan', '').str.replace("  ", " ").str.strip()
docData['Review'] = docData['Review'].fillna('')
docData['PatientName'] = docData.PatientName.fillna('')
docData['ReviewDate'] = docData['ReviewDate'].fillna('')

docData.count()
# Out:
# DocName                59462
# DocDegree              59462
# Location               59462
# PatientName            59462
# ReviewDate             59462
# OverallRating          59462
# BedsideMannerRating    59462
# WaitTimeRating         59462
# Review                 59462
# isGood                 59462
# dtype: int64

# %%
docData['ReviewWordCount'] = docData['Review'].apply(lambda x: len(x.split()))
docData.head(3)
# Out:
#           DocName DocDegree      Location                   PatientName  \
# 0  Dr. Liana Dao         MD  New York  NY  Ashley M. (Verified Patient)
# 1  Dr. Liana Dao         MD  New York  NY            a Verified Patient
# 2  Dr. Liana Dao         MD  New York  NY            a Verified Patient
#
#              ReviewDate  OverallRating  BedsideMannerRating  WaitTimeRating  \
# 0         April 7  2015              5                    5               5
# 1         April 6  2015              5                    5               5
# 2  Less than a year ago              5                    5               4
#
#                                               Review isGood  ReviewWordCount
# 0  Liana Dao is amazing ! She made me feel totall...   True               45
# 1  I was in a jam and couldn't get to my regular ...   True               78
# 2  Dr. Dao was great - she took the time to expla...   True               24

# %%
docData[docData.ReviewWordCount == 0].groupby('OverallRating').count()
# All 1,2,3 star ratings have review comments
# Happier people tend to either write long reviews or ignore writing comments.
# Out:
#                DocName  DocDegree  Location  PatientName  ReviewDate  \
# OverallRating
# 4                    7          7         7            7           7
# 5                   29         29        29           29          29
#
#                BedsideMannerRating  WaitTimeRating  Review  isGood  \
# OverallRating
# 4                                7               7       7       7
# 5                               29              29      29      29
#
#                ReviewWordCount
# OverallRating
# 4                            7
# 5                           29

# %%
docData[['OverallRating', 'BedsideMannerRating', 'WaitTimeRating', 'Review', 'ReviewWordCount']][docData.ReviewWordCount == 0].groupby('OverallRating').mean()
# Out:
#                BedsideMannerRating  WaitTimeRating  ReviewWordCount
# OverallRating
# 4                         4.000000        4.142857                0
# 5                         4.827586        4.827586                0

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
cv = CountVectorizer(stop_words='english', ngram_range=(1, 1), max_features=5000)

# %%
reviewCV = cv.fit_transform(docData.Review)

# %%
type(reviewCV)
type(docData.Review)
# Out:
# pandas.core.series.Series

# %%
cv.get_feature_names()
# Out:
# [u'00',
#  u'08am',
#  u'10',
#  u'100',
#  u'10am',
#  u'10min',
#  u'10mins',
#  u'11',
#  u'1135',
#  u'12',
#  u'13',
#  u'13th',
#  u'14',
#  u'15',
#  u'15min',
#  u'15mins',
#  u'15pm',
#  u'17',
#  u'1990',
#  u'1hr',
#  u'1pm',
#  u'1st',
#  u'20',
#  u'2005',
#  u'2009',
#  u'2012',
#  u'2014',
#  u'20mins',
#  u'23rd',
#  u'24',
#  u'24hrs',
#  u'25',
#  u'25min',
#  u'2nd',
#  u'2pm',
#  u'2x',
#  u'30',
#  u'30am',
#  u'30mins',
#  u'30pm',
#  u'31',
#  u'315',
#  u'32a',
#  u'34',
#  u'35',
#  u'35am',
#  u'35min',
#  u'36',
#  u'3pm',
#  u'3rd',
#  u'40',
#  u'40mins',
#  u'40pm',
#  u'42a',
#  u'42nd',
#  u'43',
#  u'45',
#  u'45a',
#  u'45pm',
#  u'47',
#  u'47th',
#  u'48',
#  u'4pm',
#  u'50',
#  u'55a',
#  u'5pm',
#  u'5th',
#  u'60',
#  u'6months',
#  u'75',
#  u'830am',
#  u'835am',
#  u'87',
#  u'8am',
#  u'90',
#  u'9am',
#  u'aaa',
#  u'abdominal',
#  u'abilities',
#  u'ability',
#  u'able',
#  u'abnormal',
#  u'abortions',
#  u'abrasive',
#  u'abreast',
#  u'abrupt',
#  u'absences',
#  u'absent',
#  u'absolute',
#  u'absolutely',
#  u'absurd',
#  u'abuse',
#  u'aca',
#  u'academic',
#  u'accent',
#  u'accept',
#  u'accepted',
#  u'accepts',
#  u'access',
#  u'accessed',
#  u'accessibility',
#  u'accessible',
#  u'accessing',
#  u'accident',
#  u'accidentally',
#  u'accidents',
#  u'accomadating',
#  u'accommodate',
#  u'accommodated',
#  u'accommodating',
#  u'accomodate',
#  u'accomodating',
#  u'accomplished',
#  u'according',
#  u'accordingly',
#  u'account',
#  u'accurate',
#  u'accurately',
#  u'accustomed',
#  u'ace',
#  u'ache',
#  u'acid',
#  u'acknowledge',
#  u'acknowledged',
#  u'acknowledgement',
#  u'acknowledging',
#  u'acquired',
#  u'act',
#  u'acted',
#  u'action',
#  u'actions',
#  u'active',
#  u'actively',
#  u'activist',
#  u'activities',
#  u'activity',
#  u'actual',
#  u'actually',
#  u'acupuncture',
#  u'acute',
#  u'ad',
#  u'adam',
#  u'adamian',
#  u'adams',
#  u'add',
#  u'added',
#  u'adding',
#  u'addition',
#  u'additional',
#  u'additionally',
#  u'additions',
#  u'address',
#  u'addressed',
#  u'addresses',
#  u'addressing',
#  u'adequate',
#  u'adhere',
#  u'adjusted',
#  u'adjustment',
#  u'adjusts',
#  u'adler',
#  u'admin',
#  u'administer',
#  u'administered',
#  u'administers',
#  u'administration',
#  u'administrative',
#  u'admins',
#  u'admiration',
#  u'admit',
#  u'admitted',
#  u'adopted',
#  u'adore',
#  u'adrenal',
#  u'adult',
#  u'adults',
#  u'advance',
#  u'advantage',
#  u'advertised',
#  u'advice',
#  u'advil',
#  u'advise',
#  u'advised',
#  u'advises',
#  u'advocate',
#  u'aesthetics',
#  u'affability',
#  u'affable',
#  u'affect',
#  u'affiliated',
#  u'afford',
#  u'affordable',
#  u'afraid',
#  u'afternoon',
#  u'afterward',
#  u'age',
#  u'aged',
#  u'agenda',
#  u'agent',
#  u'aggressive',
#  u'agitated',
#  u'ago',
#  u'agree',
#  u'agreed',
#  u'agreeing',
#  u'agreement',
#  u'ahead',
#  u'ahmed',
#  u'ahn',
#  u'ahold',
#  u'aid',
#  u'ailment',
#  u'ailments',
#  u'ails',
#  u'air',
#  u'airplane',
#  u'aisha',
#  u'akselrud',
#  u'akward',
#  u'al',
#  u'alarm',
#  u'alarmist',
#  u'alas',
#  u'alcoholic',
#  u'alerted',
#  u'alla',
#  u'allen',
#  u'allergic',
#  u'allergies',
#  u'allergist',
#  u'allergy',
#  u'alleviate',
#  u'alleviates',
#  u'alleviating',
#  u'allot',
#  u'allow',
#  u'allowed',
#  u'allowing',
#  u'allows',
#  u'allright',
#  u'aloof',
#  u'alot',
#  u'alright',
#  u'alstein',
#  u'alternate',
#  u'alternative',
#  u'alternatively',
#  u'alternatives',
#  u'altogether',
#  u'altstein',
#  u'amable',
#  u'amazed',
#  u'amazing',
#  u'amazingly',
#  u'amiable',
#  u'amicable',
#  u'amnot',
#  u'amounted',
#  u'ample',
#  u'amsterdam',
#  u'amy',
#  u'amzing',
#  u'ana',
#  u'anal',
#  u'anally',
#  u'analysis',
#  u'analytical',
#  u'analyze',
#  u'angioedema',
#  u'ankle',
#  u'ankles',
#  u'anna',
#  u'annoy',
#  u'annoyance',
#  u'annoyed',
#  u'annoying',
#  u'annual',
#  u'annuals',
#  u'anomaly',
#  u'ans',
#  u'answer',
#  u'answered',
#  u'answering',
#  u'answers',
#  u'anti',
#  u'antibiotic',
#  u'antibiotics',
#  u'anticipated',
#  u'anticipating',
#  u'antiobiotics',
#  u'anxiety',
#  u'anxious',
#  u'anybody',
#  u'anymore',
#  u'anytime',
#  u'apart',
#  u'apartment',
#  u'apathetic',
#  u'apmt',
#  u'apologetic',
#  u'apologize',
#  u'apologized',
#  u'apologizing',
#  u'apology',
#  u'app',
#  u'apparent',
#  u'apparently',
#  u'appeal',
#  u'appear',
#  u'appearance',
#  u'appeared',
#  u'appears',
#  u'appeased',
#  u'appendicitis',
#  u'appitnment',
#  u'appointed',
#  u'appointment',
#  u'appointments',
#  u'appraisal',
#  u'appreciate',
#  u'appreciated',
#  u'appreciation',
#  u'appreciative',
#  u'appriciated',
#  u'approach',
#  u'approachable',
#  u'approaches',
#  u'appropriate',
#  u'appropriately',
#  u'approx',
#  u'approximately',
#  u'appt',
#  u'appts',
#  u'april',
#  u'aproach',
#  u'aprons',
#  u'apt',
#  u'aran',
#  u'area',
#  u'areas',
#  u'aren',
#  u'argie',
#  u'arguing',
#  u'arise',
#  u'arm',
#  u'arms',
#  u'arrange',
#  u'arranged',
#  u'array',
#  u'arrival',
#  u'arrive',
#  u'arrived',
#  u'arriving',
#  u'arrogance',
#  u'arrogant',
#  u'art',
#  u'arthritis',
#  u'articles',
#  u'articulate',
#  u'artist',
#  u'asap',
#  u'ashamed',
#  u'aside',
#  u'ask',
#  u'asked',
#  u'askelrud',
#  u'asking',
#  u'asks',
#  u'aspect',
#  u'aspects',
#  u'assembly',
#  u'assess',
#  u'assessed',
#  u'assessing',
#  u'assessment',
#  u'assessments',
#  u'asset',
#  u'assist',
#  u'assistance',
#  u'assistant',
#  u'assistants',
#  u'assisted',
#  u'assists',
#  u'assitant',
#  u'associated',
#  u'asst',
#  u'assume',
#  u'assumed',
#  u'assuming',
#  u'assumptions',
#  u'assure',
#  u'assured',
#  u'assures',
#  u'assuring',
#  u'ast',
#  u'asthma',
#  u'astoria',
#  u'astute',
#  u'ate',
#  u'atm',
#  u'atmosphere',
#  u'attacks',
#  u'attempt',
#  u'attempted',
#  u'attempting',
#  u'attempts',
#  u'attend',
#  u'attendant',
#  u'attended',
#  u'attending',
#  u'attention',
#  u'attentive',
#  u'attentively',
#  u'attentiveness',
#  u'attire',
#  u'attitude',
#  u'attitudes',
#  u'attoe',
#  u'attorney',
#  u'attractive',
#  u'attribute',
#  u'attributed',
#  u'attributes',
#  u'attuned',
#  u'auerbach',
#  u'aunt',
#  u'aura',
#  u'australia',
#  u'author',
#  u'automatically',
#  u'autonomy',
#  u'availabilities',
#  u'availability',
#  u'available',
#  u'ave',
#  u'avenue',
#  u'average',
#  u'avoid',
#  u'avoided',
#  u'avoids',
#  u'aware',
#  u'away',
#  u'awesome',
#  u'awful',
#  u'awhile',
#  u'awkward',
#  u'awsome',
#  u'azar',
#  u'azithromycin',
#  u'aziz',
#  u'babaeva',
#  u'baby',
#  u'backed',
#  u'background',
#  u'bad',
#  u'badgered',
#  u'bag',
#  u'bagner',
#  u'bailyn',
#  u'balance',
#  u'balanced',
#  u'ball',
#  u'bandaid',
#  u'bank',
#  u'banter',
#  u'barbituates',
#  u'bare',
#  u'barefoot',
#  u'barely',
#  u'barred',
#  u'barry',
#  u'base',
#  u'based',
#  u'basement',
#  u'bases',
#  u'basic',
#  u'basically',
#  u'basis',
#  u'bat',
#  u'bathroom',
#  u'bathrooms',
#  u'battery',
#  u'battling',
#  u'bc',
#  u'bearable',
#  u'beat',
#  u'beating',
#  u'beautiful',
#  u'bed',
#  u'bedroom',
#  u'bedside',
#  u'beeing',
#  u'beer',
#  u'bees',
#  u'began',
#  u'begin',
#  u'beginning',
#  u'behalf',
#  u'behaved',
#  u'behavior',
#  u'behold',
#  u'believe',
#  u'believes',
#  u'belittling',
#  u'bell',
#  u'bella',
#  u'belly',
#  u'belongs',
#  u'benefit',
#  u'benefits',
#  u'benign',
#  u'berk',
#  u'bernard',
#  u'bertie',
#  u'bertisch',
#  u'best',
#  u'bet',
#  u'beth',
#  u'better',
#  u'beuria',
#  u'beverly',
#  u'beware',
#  u'bhat',
#  u'bickman',
#  u'big',
#  u'bigger',
#  u'biggest',
#  u'bikhman',
#  u'bikman',
#  u'billed',
#  u'billing',
#  u'bills',
#  u'biology',
#  u'biometrics',
#  u'biopsy',
#  u'birth',
#  u'bit',
#  u'bizarre',
#  u'blackberry',
#  u'blacked',
#  u'blah',
#  u'blame',
#  u'blamed',
#  u'blasting',
#  u'bless',
#  u'blessed',
#  u'blessing',
#  u'blew',
#  u'blizzard',
#  u'block',
#  u'blocks',
#  u'blood',
#  u'bloods',
#  u'bloodwork',
#  u'blowing',
#  u'blown',
#  u'blue',
#  u'blunt',
#  u'board',
#  u'body',
#  u'boisterous',
#  u'bomb',
#  u'bone',
#  u'bones',
#  u'bonus',
#  u'book',
#  u'booked',
#  u'booking',
#  u'bookings',
#  u'books',
#  u'boom',
#  u'boot',
#  u'bordering',
#  u'bored',
#  u'borges',
#  u'born',
#  u'bother',
#  u'bothered',
#  u'bothering',
#  u'botox',
#  u'bottle',
#  u'boutique',
#  u'box',
#  u'boxes',
#  u'boy',
#  u'boyfriend',
#  u'boys',
#  u'bp',
#  u'brain',
#  u'brained',
#  u'brand',
#  u'brash',
#  u'break',
#  u'breaking',
#  u'breaks',
#  u'breast',
#  u'breath',
#  u'breathing',
#  u'breeze',
#  u'bregman',
#  u'breite',
#  u'brief',
#  u'briefly',
#  u'brien',
#  u'bright',
#  u'brilliant',
#  u'bring',
#  u'bringing',
#  u'brings',
#  u'broad',
#  u'broadway',
#  u'broken',
#  u'bronchial',
#  u'bronchitis',
#  u'bronx',
#  u'brooklyn',
#  u'broom',
#  u'brought',
#  u'brown',
#  u'brownlow',
#  u'brush',
#  u'brushed',
#  u'brusque',
#  u'bs',
#  u'btw',
#  u'bubbly',
#  u'bucker',
#  u'buckner',
#  u'budget',
#  u'bueno',
#  u'buggy',
#  u'build',
#  u'building',
#  u'buildings',
#  u'built',
#  u'bull',
#  u'bunch',
#  u'burack',
#  u'burden',
#  u'burdening',
#  u'bureaucracy',
#  u'burning',
#  u'burton',
#  u'business',
#  u'businesslike',
#  u'businessman',
#  u'busy',
#  u'button',
#  u'buy',
#  u'bye',
#  u'cab',
#  u'caesar',
#  u'caitlin',
#  u'cake',
#  u'calderon',
#  u'calf',
#  u'cali',
#  u'california',
#  u'called',
#  u'calling',
#  u'calls',
#  u'calm',
#  u'calmed',
#  u'calming',
#  u'calmly',
#  u'calms',
#  u'came',
#  u'cancel',
#  u'canceling',
#  u'cancelled',
#  u'cancer',
#  u'candid',
#  u'capable',
#  u'capacity',
#  u'capitalize',
#  u'car',
#  u'card',
#  u'cardiac',
#  u'cardiologist',
#  u'cardiologists',
#  u'cardiology',
#  u'cardiovascular',
#  u'cards',
#  u'care',
#  u'cared',
#  u'career',
#  u'careful',
#  u'carefully',
#  u'caregivers',
#  u'careless',
#  u'cares',
#  u'caring',
#  u'carloina',
#  u'carlos',
#  u'carol',
#  u'carolina',
#  u'carreno',
#  u'carried',
#  u'carries',
#  u'carron',
#  u'carry',
#  u'carts',
#  u'case',
#  u'cases',
#  u'cash',
#  u'casual',
#  u'casually',
#  u'catch',
#  u'cathy',
#  u'cattle',
#  u'caught',
#  u'cause',
#  u'caused',
#  u'causes',
#  u'causing',
#  u'cautious',
#  u'cbc',
#  u'cc',
#  u'cease',
#  u'ceiling',
#  u'cell',
#  u'cellphone',
#  u'cellphones',
#  u'cells',
#  u'center',
#  u'centered',
#  u'centers',
#  u'central',
#  u'centre',
#  u'centrifuge',
#  u'certain',
#  u'certainly',
#  u'certified',
#  u'cha',
#  u'chain',
#  u'chair',
#  u'chairs',
#  u'chalant',
#  u'challenge',
#  u'challenging',
#  u'chan',
#  u'chance',
#  u'change',
#  u'changed',
#  u'changes',
#  u'changing',
#  u'channel',
#  u'chaotic',
#  u'character',
#  u'characteristic',
#  u'characteristics',
#  u'charge',
#  u'charged',
#  u'charges',
#  u'charging',
#  u'charismatic',
#  u'charm',
#  u'charming',
#  u'chart',
#  u'charts',
#  u'chase',
#  u'chased',
#  u'chastised',
#  u'chat',
#  u'chatterjee',
#  u'chatting',
#  u'chatty',
#  u'cheap',
#  u'check',
#  u'checked',
#  u'checkin',
#  u'checking',
#  u'checkout',
#  u'checks',
#  u'checkup',
#  u'checkups',
#  u'cheerful',
#  u'cheesy',
#  u'chelsea',
#  u'chemistry',
#  u'chest',
#  u'cheung',
#  u'chewing',
#  u'chi',
#  u'chief',
#  u'child',
#  u'childhood',
#  u'children',
#  u'chill',
#  u'chilled',
#  u'chinai',
#  u'chinatown',
#  u'chiropractor',
#  u'chit',
#  u'chitchat',
#  u'cho',
#  u'choatic',
#  u'choice',
#  u'choices',
#  u'choose',
#  u'choosing',
#  u'chop',
#  u'chose',
#  u'chosen',
#  u'christine',
#  u'chronic',
#  u'chuey',
#  u'chung',
#  u'churn',
#  u'cigs',
#  u'cindy',
#  u'circumstances',
#  u'citing',
#  u'city',
#  u'citymd',
#  u'claim',
#  u'claimed',
#  u'claire',
#  u'clarification',
#  u'clarified',
#  u'clarity',
#  u'class',
#  u'clean',
#  u'cleaned',
#  u'cleaner',
#  u'cleanest',
#  u'cleaning',
#  u'cleanliness',
#  u'clear',
#  u'clearance',
#  u'cleared',
#  u'clearer',
#  u'clearly',
#  u'click',
#  u'client',
#  u'clients',
#  u'clinic',
#  u'clinical',
#  u'clinician',
#  u'clinics',
#  u'clipboard',
#  u'clock',
#  u'close',
#  u'closed',
#  u'closely',
#  u'closer',
#  u'closet',
#  u'clot',
#  u'clothes',
#  u'clueless',
#  u'cluttered',
#  u'coat',
#  u'coddle',
#  u'code',
#  u'codella',
#  u'codes',
#  u'coffee',
#  u'cohen',
#  u'cold',
#  u'colic',
#  u'collaborative',
#  u'colleague',
#  u'colleagues',
#  u'collected',
#  u'collecting',
#  u'collection',
#  u'collections',
#  u'college',
#  u'colonoscopy',
#  u'colorful',
#  u'colors',
#  u'com',
#  u'combination',
#  u'combined',
#  u'come',
#  u'comes',
#  u'comfort',
#  u'comfortable',
#  u'comforted',
#  u'comforting',
#  u'comforts',
#  u'coming',
#  u'commended',
#  u'comment',
#  u'commented',
#  u'comments',
#  u'commitment',
#  u'committed',
#  u'common',
#  u'communal',
#  u'communicate',
#  u'communicated',
#  u'communicates',
#  u'communicating',
#  u'communication',
#  u'communications',
#  u'communicative',
#  u'communicator',
#  u'community',
#  u'commute',
#  u'como',
#  u'comp',
#  u'companies',
#  u'company',
#  u'compared',
#  u'compares',
#  u'comparison',
#  u'compassion',
#  u'compassionate',
#  u'compelled',
#  u'competence',
#  u'competent',
#  u'complain',
#  u'complained',
#  u'complaining',
#  u'complains',
#  u'complaint',
#  u'complaints',
#  u'complete',
#  u'completed',
#  u'completely',
#  u'completing',
#  u'complex',
#  u'complexion',
#  u'complicated',
#  u'complication',
#  u'comprehensive',
#  u'computer',
#  u'concentration',
#  u'concered',
#  u'concern',
#  u'concerned',
#  u'concerning',
#  u'concerns',
#  u'concise',
#  u'concisely',
#  u'conclude',
#  u'concluded',
#  u'conclusion',
#  u'conclusions',
#  u'concrete',
#  u'concurred',
#  u'condescending',
#  u'condescension',
#  u'condition',
#  u'conditions',
#  u'conduct',
#  u'conducted',
#  u'conference',
#  u'confidant',
#  u'confide',
#  u'confidence',
#  u'confident',
#  u'confirm',
#  u'confirmation',
#  u'confirmations',
#  u'confirmed',
#  u'confirming',
#  u'conflict',
#  u'confused',
#  u'confusing',
#  u'confusion',
#  u'congenial',
#  u'congestion',
#  u'connect',
#  u'connected',
#  u'connection',
#  u'connie',
#  u'cons',
#  u'conscience',
#  u'conscientious',
#  u'conscious',
#  u'consent',
#  u'conservative',
#  u'consider',
#  u'considerable',
#  u'considerate',
#  u'consideration',
#  u'considered',
#  u'considering',
#  u'considers',
#  u'consisted',
#  u'consistent',
#  u'consistently',
#  u'consolation',
#  u'constantly',
#  u'construction',
#  u'consulation',
#  u'consult',
#  u'consultation',
#  u'consultations',
#  u'consulted',
#  u'consulting',
#  u'consumable',
#  u'consumed',
#  u'consumer',
#  u'consuming',
#  u'consummate',
#  u'contact',
#  u'contacted',
#  ...]

# %%
# Classification techniques to predict if a review is Good Or Not
# Linear Regression with Polynomial features gets too complicated and my system craps

# %%
docDataWReview = reviewCV.toarray()

# %%
docData.describe()
# Out:
#        OverallRating  BedsideMannerRating  WaitTimeRating     isGood  \
# count   59462.000000         59462.000000    59462.000000      59462
# mean        4.623541             4.672093        4.325334  0.9048972
# std         0.934691             0.813151        0.826189  0.2933593
# min         1.000000             1.000000        1.000000      False
# 25%         5.000000             5.000000        4.000000          1
# 50%         5.000000             5.000000        5.000000          1
# 75%         5.000000             5.000000        5.000000          1
# max         5.000000             5.000000        5.000000       True
#
#        ReviewWordCount
# count     59462.000000
# mean         32.016902
# std          36.879769
# min           0.000000
# 25%          10.000000
# 50%          22.000000
# 75%          41.000000
# max         606.000000

# %%
docData[docData.isGood == False].count().max()
# Out:
# 5655

# %%
for x in xrange(1,6):
    print 'Rating is %d count is %d' %(x, docData[docData.OverallRating == x].count().max())
# Out:
# Rating is 1 count is 1820
# Rating is 2 count is 2120
# Rating is 3 count is 1715
# Rating is 4 count is 5315
# Rating is 5 count is 48492

# %%
#### Data is skewed towards higher ratings

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import cross_val_score

# %%
# %%time
# model = LogisticRegression(penalty='l1', C=100)
model = LogisticRegression()
# Out:
# CPU times: user 39 µs, sys: 5 µs, total: 44 µs
# Wall time: 60.1 µs

# %%
# %%time
X = docDataWReview
print cross_val_score(model, X, docData.isGood, cv=5, scoring='roc_auc').mean()
# Out:
# 0.990964341002
# CPU times: user 19.6 s, sys: 47.6 s, total: 1min 7s
# Wall time: 1min 23s

# %%
print cross_val_score(model, X, docData.isGood, cv=5).mean()
# Out:
# 0.9868990595

# %%
#Super high accuracy !??? .... Data is skewed?
# 91% of the data set has Good Rating as per our definition

# %%
print cross_val_score(model, X, docData.isGood, cv=5, scoring='precision').mean()
# Precision is important here.
# There are many positives in the real data. So we want to weigh the model against False positive.
# So that it avoids false positives.
# 98.98% precision means lesser false positives. Thus the model is not dumbly saying all cases as positives.
# Out:
# 0.987963947367

# %%
print cross_val_score(model, X, docData.isGood, cv=5, scoring='recall').mean()
# Out:
# 0.997695462638

# %%
#### Test using Test data set
model.fit(X,docData.isGood)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
docTestData = pd.read_csv(path_to_data + 'test.csv')

# %%
docTestData = docTestData.dropna()

# %%
docTestData['isGoodTest'] = docTestData.OverallRating.apply(lambda x: x-3 >0)

# %%
docTestData.describe()
# Out:
#        OverallRating  BedsideMannerRating  WaitTimeRating isGoodTest
# count   51779.000000         51779.000000    51779.000000      51779
# mean        4.652697             4.701018        4.291894  0.9141158
# std         0.887807             0.776808        0.841169  0.2801957
# min         1.000000             1.000000        1.000000      False
# 25%         5.000000             5.000000        4.000000          1
# 50%         5.000000             5.000000        4.000000          1
# 75%         5.000000             5.000000        5.000000          1
# max         5.000000             5.000000        5.000000       True

# %%
reviewCVTest = cv.transform(docTestData.Review)

# %%
X_test=reviewCVTest.toarray()
Y_test=docTestData.isGoodTest

# %%
model.score(X_test, Y_test)
# Out:
# 0.9839123969176693

# %%
#98% accurate
#How to check precision and roc?
